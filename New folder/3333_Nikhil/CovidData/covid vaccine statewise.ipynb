# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
print("installed")
# Out:
# installed

# %%
#read file
url="covid_vaccine_statewise.csv"
vaccine_df = pd.read_csv(url,index_col="Updated On", parse_dates=True, dayfirst=True)

print("completed")
# Out:
# completed

# %%
vaccine_df.shape
# Out:
# (7845, 23)

# %%
print(vaccine_df)
# Out:
#                   State  Total Doses Administered  Sessions   Sites   \
# Updated On
# 2021-01-16        India                   48276.0    3455.0   2957.0
# 2021-01-17        India                   58604.0    8532.0   4954.0
# 2021-01-18        India                   99449.0   13611.0   6583.0
# 2021-01-19        India                  195525.0   17855.0   7951.0
# 2021-01-20        India                  251280.0   25472.0  10504.0
# ...                 ...                       ...       ...      ...
# 2021-08-11  West Bengal                       NaN       NaN      NaN
# 2021-08-12  West Bengal                       NaN       NaN      NaN
# 2021-08-13  West Bengal                       NaN       NaN      NaN
# 2021-08-14  West Bengal                       NaN       NaN      NaN
# 2021-08-15  West Bengal                       NaN       NaN      NaN
#
#             First Dose Administered  Second Dose Administered  \
# Updated On
# ...

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7845 entries, 2021-01-16 to 2021-08-15
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                7845 non-null   object
#  1   Total Doses Administered             7621 non-null   float64
#  2   Sessions                             7621 non-null   float64
#  3    Sites                               7621 non-null   float64
#  4   First Dose Administered              7621 non-null   float64
#  5   Second Dose Administered             7621 non-null   float64
#  6   Male (Doses Administered)            7461 non-null   float64
#  7   Female (Doses Administered)          7461 non-null   float64
#  8   Transgender (Doses Administered)     7461 non-null   float64
#  9    Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
vaccine_df.head()
# Out:
#             State  Total Doses Administered  Sessions   Sites   \
# Updated On
# 2021-01-16  India                   48276.0    3455.0   2957.0
# 2021-01-17  India                   58604.0    8532.0   4954.0
# 2021-01-18  India                   99449.0   13611.0   6583.0
# 2021-01-19  India                  195525.0   17855.0   7951.0
# 2021-01-20  India                  251280.0   25472.0  10504.0
#
#             First Dose Administered  Second Dose Administered  \
# Updated On
# 2021-01-16                  48276.0                       0.0
# 2021-01-17                  58604.0                       0.0
# 2021-01-18                  99449.0                       0.0
# 2021-01-19                 195525.0                       0.0
# 2021-01-20                 251280.0                       0.0
#
#             Male (Doses Administered)  Female (Doses Administered)  \
# Updated On
# 2021-01-16                        NaN                          NaN
# ...

# %%
#vaccine_df['Male(Individuals Vaccinated)'].sum()
print('Total Female vaccinated all over India = ',vaccine_df.groupby('State')['Male(Individuals Vaccinated)'].max().India)
# Out:
# Total Female vaccinated all over India =  134941971.0

# %%
print('Total Female vaccinated all over India = ',vaccine_df.groupby('State')['Female(Individuals Vaccinated)'].max().India)
# Out:
# Total Female vaccinated all over India =  115668447.0

# %%
vaccine_df.groupby('State')['First Dose Administered'].max()
# Out:
# State
# Andaman and Nicobar Islands                    216046.0
# Andhra Pradesh                               17628583.0
# Arunachal Pradesh                              692475.0
# Assam                                        10495293.0
# Bihar                                        23350171.0
# Chandigarh                                     700285.0
# Chhattisgarh                                  9181482.0
# Dadra and Nagar Haveli and Daman and Diu       584370.0
# Delhi                                         7835546.0
# Goa                                           1094392.0
# Gujarat                                      28101222.0
# Haryana                                      10086831.0
# Himachal Pradesh                              4249849.0
# India                                       400150406.0
# Jammu and Kashmir                             5318516.0
# Jharkhand                                     8382280.0
# Karnataka                                    25847691.0
# ...

# %%
vaccine_df.groupby('State')['Second Dose Administered'].max()
# Out:
# State
# Andaman and Nicobar Islands                     94597.0
# Andhra Pradesh                                6214312.0
# Arunachal Pradesh                              186619.0
# Assam                                         2208577.0
# Bihar                                         4484768.0
# Chandigarh                                     223534.0
# Chhattisgarh                                  2587695.0
# Dadra and Nagar Haveli and Daman and Diu        80851.0
# Delhi                                         3000536.0
# Goa                                            302519.0
# Gujarat                                       9051153.0
# Haryana                                       2923550.0
# Himachal Pradesh                              1382592.0
# India                                       113077994.0
# Jammu and Kashmir                             1489826.0
# Jharkhand                                     1996014.0
# Karnataka                                     7432852.0
# ...
